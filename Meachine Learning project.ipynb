# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sss=pd.read_csv("SampleSuperStore.csv")
sss
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sss.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# std                NaN       NaN            NaN            NaN         NaN
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
# checking for null value
sss.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
sss.shape
# Out:
# (9994, 13)

# %%
sss.duplicated().sum()
# Out:
# 17

# %%
sss.drop_duplicates(subset=None, inplace=True)

# %%
sss.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
sss.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Group by Category and calculate total sales
sales_by_category = sss.groupby('Category')['Sales'].sum().sort_values()

# %%
# Plotting the bar graph
plt.figure(figsize=(8, 4))
sales_by_category.plot(kind='bar', color='blue')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=0)
plt.show()

# %%
profit_by_region = sss.groupby('Region')['Profit'].sum().sort_values()

# %%
plt.figure(figsize=(8, 4))
profit_by_region.plot(kind='bar', color='blue')
plt.title('Total Profit by Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.xticks(rotation=0)
plt.show()

# %%
# Group by Category and calculate total sales
sales_by_subcategory = sss.groupby('Sub-Category')['Sales'].sum().sort_values()

# %%
# Plotting the bar graph
plt.figure(figsize=(8, 4))
sales_by_subcategory.plot(kind='bar', color='blue')
plt.title('Total Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.show()

# %%
#stacked Bargraph
# grouping category sales and profit
CSP=sss.groupby('Category')[['Sales','Profit']].sum()

# %%
CSP.plot(kind='bar',stacked=True,color=['skyblue','orange'],figsize=(8,4))
plt.title('Sales and Profit by Category')
plt.xlabel('Category')
plt.ylabel('Amount')
plt.xticks(rotation=0)
plt.show()

# %%
#creating scater plot
plt.figure(figsize=(8,4))
plt.scatter(sss['Sales'],sss['Profit'],alpha=0.5,color='blue')
plt.title('Profit vs Sales')
plt.ylabel('sales')
plt.xlabel('Profit')
plt.grid=True
plt.show()

# %%
plt.boxplot(sss.Discount)
plt.show()

# %%
# Grouping data by region to calculate sales and profit contributions
region_summary = sss.groupby('Region')[['Sales', 'Profit']].sum()

# Pie chart for Sales and Profit by Region
fig, axes = plt.subplots(1, 2, figsize=(8, 7))

# Sales contribution pie chart
axes[0].pie(region_summary['Sales'], labels=region_summary.index, autopct='%1.1f%%', startangle=140)
axes[0].set_title('Sales Contribution by Region')

# Profit contribution pie chart
axes[1].pie(region_summary['Profit'], labels=region_summary.index, autopct='%1.1f%%', startangle=140)
axes[1].set_title('Profit Contribution by Region')

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encode = LabelEncoder()
categorical_columns=['Ship Mode','Segment','Country', 'City', 'State', 'Postal Code',
       'Region', 'Category', 'Sub-Category']
for column in categorical_columns:
    sss[column]=encode.fit_transform(sss[column])

# %%
from sklearn.linear_model import LogisticRegression  
from sklearn.metrics import accuracy_score

# %%
# changing profit to binary form
sss['Profit_Binary']=(sss['Profit']>0).astype(int)
# machine learning spliting into input and out put
X= sss.iloc[: , :-1]
Y= sss.Profit
Y=sss['Profit_Binary']

# %%
from sklearn.model_selection import train_test_split

# %%
xtr,xts,ytr,yts= train_test_split(X,Y,test_size= 0.5)

# %%
accuracies= []
model= LogisticRegression(max_iter=i)
model.fit(xtr,ytr)                                   # BY changing profit into binar form now its posiible for LogisticRegression
ypr = model.predict(xts)
accuracies.append(accuracy_score(yts,ypr)*100)
accuracies
# Out:
# C:\Users\Liyon Sabastian\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [93.64602124674283]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
accu = []
for i in range(2,11):
    model= DecisionTreeClassifier(max_depth=10)                     #  DecisonTreeClassifier is now possible
    model.fit(xtr,ytr)                                              
    ypr = model.predict(xts)
    print(f' the accuracy of decision tree with depth{i} is {accuracy_score(yts,ypr)*100}')
# Out:
#  the accuracy of decision tree with depth2 is 100.0
#  the accuracy of decision tree with depth3 is 100.0
#  the accuracy of decision tree with depth4 is 100.0
#  the accuracy of decision tree with depth5 is 100.0
#  the accuracy of decision tree with depth6 is 100.0
#  the accuracy of decision tree with depth7 is 100.0
#  the accuracy of decision tree with depth8 is 100.0
#  the accuracy of decision tree with depth9 is 100.0
#  the accuracy of decision tree with depth10 is 100.0

# %%
model= DecisionTreeClassifier(max_depth=6)
model.fit(xtr,ytr)
ypr = model.predict(xts)
accuracies.append(accuracy_score(yts,ypr)*100)
accuracies
# Out:
# [100.0]

# %%
# SVM
from sklearn.svm import SVC
model= SVC()                                 
model.fit(xtr,ytr)
ypr = model.predict(xts)
accuracies.append(accuracy_score(yts,ypr)*100)
accuracies
# Out:
# [100.0, 89.53698135898978]

# %%
# naive bias 
from sklearn.naive_bayes import GaussianNB
model= GaussianNB()
model.fit(xtr,ytr)                                 
ypr = model.predict(xts)
accuracies.append(accuracy_score(yts,ypr)*100)
accuracies
# Out:
# [100.0, 89.53698135898978, 92.72399278412507]

# %%
# KNN
from sklearn.neighbors import KNeighborsClassifier
for i in range(2,11):
    model= KNeighborsClassifier(n_neighbors=i)
    model.fit(xtr,ytr)                                 # Best Accuracy at 9th iteration= 81.73982762076568
    ypr = model.predict(xts)
    print(f' the accuracy of KNN with {i} is {accuracy_score(yts,ypr)*100}')
# Out:
#  the accuracy of KNN with 2 is 92.9444778512728
#  the accuracy of KNN with 3 is 93.2852275005011
#  the accuracy of KNN with 4 is 92.9444778512728
#  the accuracy of KNN with 5 is 92.8041691721788
#  the accuracy of KNN with 6 is 92.44337542593706
#  the accuracy of KNN with 7 is 91.60152335137302
#  the accuracy of KNN with 8 is 91.78192022449389
#  the accuracy of KNN with 9 is 91.26077370214472
#  the accuracy of KNN with 10 is 91.46121467227901

# %%
model= KNeighborsClassifier(n_neighbors=9)
model.fit(xtr,ytr)
ypr = model.predict(xts)
accuracies.append(accuracy_score(yts,ypr)*100)
accuracies
# Out:
# [100.0, 89.53698135898978, 92.72399278412507, 91.26077370214472]

# %%
# applying RandomForest
from sklearn.ensemble import RandomForestClassifier
for i in range(2,11):
    model= RandomForestClassifier(max_depth=i)
    model.fit(xtr,ytr)
    ypr = model.predict(xts)
    print(f' the accuracy of Random forest with {i} is {accuracy_score(yts,ypr)*100}')
# Out:
#  the accuracy of Random forest with 2 is 99.61916215674484
#  the accuracy of Random forest with 3 is 100.0
#  the accuracy of Random forest with 4 is 100.0
#  the accuracy of Random forest with 5 is 100.0
#  the accuracy of Random forest with 6 is 100.0
#  the accuracy of Random forest with 7 is 100.0
#  the accuracy of Random forest with 8 is 100.0
#  the accuracy of Random forest with 9 is 100.0
#  the accuracy of Random forest with 10 is 100.0

# %%
model= RandomForestClassifier(max_depth=9)
model.fit(xtr,ytr)
ypr = model.predict(xts)
accuracies.append(accuracy_score(yts,ypr)*100)
accuracies
# Out:
# [100.0, 89.53698135898978, 92.72399278412507, 91.26077370214472, 100.0]

# %%
#  comparing all accuracies
ML_algo= ['Logistic Reg','Decision Tree','SVM','Naive Bayes','KNN','Random Foest']
plt.barh(ML_algo,accuracies,color= 'red')
plt.ylabel('Accuracy percentage')
plt.xlabel('Algorithm applied')
plt.show()
